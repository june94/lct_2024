# %%
# %pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import torch
from ultralytics import YOLO

# %%
model_path = "/home/jupyter/datasphere/project/logs/yolo_gpu/weights/best.pt"
model = YOLO(model_path)  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
print(metrics.box.map,  # map50-95
metrics.box.map50,  # map50
metrics.box.map75,  # map75
metrics.box.maps)  # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /home/jupyter/work/resources/data/test/labels.cache... 17794 images, 0 backgrounds, 0 corrupt: 100%|██████████| 17794/17794 [00:00<?, ?it/s]
# val: WARNING ⚠️ /home/jupyter/work/resources/data/test/images/4f6335afb880904ed5ebae7ed55fd81b_init_labels.png: corrupt JPEG restored and saved
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1113/1113 [06:03<00:00,  3.06it/s]
#                    all      17794      18330      0.794      0.679      0.706       0.43
#                  drone       3869       4267      0.744      0.636      0.648      0.316
#                  plane       4615       4615      0.726      0.821      0.821      0.592
#                   heli       2603       2603      0.977      0.983      0.993      0.727
# ...

# %%
import os

load_path = "/home/jupyter/datasphere/project/data/test/images"
save_path = "/home/jupyter/datasphere/project/result"

for img in os.listdir(load_path):
    result = model([os.path.join(load_path, img)])
    #boxes = result.boxes  # Boxes object for bounding box outputs
    #masks = result.masks  # Masks object for segmentation masks outputs
    #keypoints = result.keypoints  # Keypoints object for pose outputs
    #probs = result.probs  # Probs object for classification outputs
    #obb = result.obb  # Oriented boxes object for OBB outputs
    #result.show()  # display to screen
    result[0].save(filename=os.path.join(save_path, img))
# Out:
# 0: 352x640 (no detections), 76.4ms
# Speed: 3.6ms preprocess, 76.4ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 5.6ms
# Speed: 1.7ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 5.9ms
# Speed: 1.8ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 5.5ms
# Speed: 1.7ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 5.5ms
# Speed: 1.6ms preprocess, 5.5ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 drone, 5.5ms
# Speed: 1.9ms preprocess, 5.5ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 drone, 5.5ms
# Speed: 1.7ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 5.5ms
# ...

# %%
torch.backends.cudnn.enabled = False

exp_name = "yolo_gpu_resume" 
project = "/home/jupyter/datasphere/project/logs"
model_path = "/home/jupyter/datasphere/project/logs/yolo_gpu/weights/last.pt" #"/home/jupyter/datasphere/project/weights/yolov8n.pt"
config_path = "/home/jupyter/datasphere/project/configs/yolo8p2_n.yaml"
data_path = "/home/jupyter/datasphere/project/configs/data.yaml"
train_config_path = f"/home/jupyter/datasphere/project/configs/{exp_name}.yaml" 

model = YOLO(model_path)
results = model.train(data=data_path,
                      cfg=train_config_path, 
                      project=project,
                      name=exp_name,)
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.2.29 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
torch.backends.cudnn.enabled = False

exp_name = "yolo_gpu_resume" 
project = "/home/jupyter/datasphere/project/logs"
model_path = "/home/jupyter/datasphere/project/logs/yolo_gpu/weights/last.pt" #"/home/jupyter/datasphere/project/weights/yolov8n.pt"
config_path = "/home/jupyter/datasphere/project/configs/yolo8p2_n.yaml"
data_path = "/home/jupyter/datasphere/project/configs/data.yaml"
train_config_path = f"/home/jupyter/datasphere/project/configs/{exp_name}.yaml" 

model = YOLO(config_path) 
model = YOLO(model_path)
results = model.train(data=data_path,
                      cfg=train_config_path, 
                      project=project,
                      name=exp_name,)
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
